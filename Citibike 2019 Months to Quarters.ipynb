# %%
import pandas as pd

# %%
jan_2019 = "Resources/201901-citibike-tripdata.csv"

feb_2019 = "Resources/201902-citibike-tripdata.csv"

mar_2019 = "Resources/201903-citibike-tripdata.csv"

# %%
jan_df = pd.read_csv(jan_2019)

feb_df = pd.read_csv(feb_2019)

mar_df = pd.read_csv(mar_2019)

# %%
mar_df.head(10)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1463  2019-03-01 00:00:16.0970  2019-03-01 00:24:39.3880
# 1           285  2019-03-01 00:00:32.3850  2019-03-01 00:05:18.1830
# 2           686  2019-03-01 00:00:47.7970  2019-03-01 00:12:14.3090
# 3           442  2019-03-01 00:01:01.2090  2019-03-01 00:08:23.7510
# 4          2913  2019-03-01 00:01:09.2810  2019-03-01 00:49:42.3810
# 5          1682  2019-03-01 00:01:27.1150  2019-03-01 00:29:29.7530
# 6           769  2019-03-01 00:01:30.0590  2019-03-01 00:14:19.9170
# 7           483  2019-03-01 00:01:33.0960  2019-03-01 00:09:36.4430
# 8           472  2019-03-01 00:01:37.0240  2019-03-01 00:09:29.4480
# 9          3198  2019-03-01 00:02:01.6940  2019-03-01 00:55:20.6360
#
#    start station id        start station name  start station latitude  \
# 0             319.0      Fulton St & Broadway               40.711066
# 1             439.0            E 4 St & 2 Ave               40.726281
# ...

# %%
Q1_df = pd.concat(map(pd.read_csv, ['Resources/201901-citibike-tripdata.csv', 'Resources/201902-citibike-tripdata.csv','Resources/201903-citibike-tripdata.csv']))

# %%
Q2_df = pd.concat(map(pd.read_csv, ['Resources/201904-citibike-tripdata.csv', 'Resources/201905-citibike-tripdata.csv','Resources/201906-citibike-tripdata.csv']))

# %%
Q3_df = pd.concat(map(pd.read_csv, ['Resources/201907-citibike-tripdata.csv', 'Resources/201908-citibike-tripdata.csv','Resources/201909-citibike-tripdata.csv']))

# %%
Q4_df = pd.concat(map(pd.read_csv, ['Resources/201910-citibike-tripdata.csv', 'Resources/201911-citibike-tripdata.csv','Resources/201912-citibike-tripdata.csv']))

# %%
Q1_df.to_csv('Resources\combinded\Q1.csv', index = True, header=True)

# %%
Q2_df.to_csv('Resources\combinded\Q2.csv', index = True, header=True)

# %%
Q3_df.to_csv('Resources\combinded\Q3.csv', index = True, header=True)

# %%
Q4_df.to_csv('Resources\combinded\Q4.csv', index = True, header=True)
